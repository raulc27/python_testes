# %% [markdown]
# <a href="https://colab.research.google.com/github/raulc27/python_testes/blob/master/cryptomoedas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install investpy
import investpy
# Out:
# ...
#      |████████████████████████████████| 4.4 MB 8.4 MB/s
# ...
#      |████████████████████████████████| 235 kB 54.9 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 23.6 MB/s
# ...
#      |████████████████████████████████| 503 kB 32.3 MB/s
# ...
#   Created wheel for investpy: filename=investpy-1.0.7-py3-none-any.whl size=4495221 sha256=8a019af90ee26ec9139f8638b0ac69e3e06880438c5f8739c892f5dd5a2c8953
#   Stored in directory: /root/.cache/pip/wheels/50/bb/ee/760eeb6cc7ed8efc1b1b23b13b6b9f17fb1ed530fb04bd16f5
# Successfully built investpy
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
bitcoin = investpy.get_crypto_historical_data(crypto='bitcoin', from_date='01/01/2020', to_date='06/11/2021')
bitcoin.head()
# Out:
#               Open    High     Low   Close  Volume Currency
# Date
# 2020-01-01  7196.4  7259.4  7180.0  7199.8  420278      USD
# 2020-01-02  7199.7  7209.6  6901.4  6967.0  632778      USD
# 2020-01-03  6967.1  7402.9  6884.1  7343.1  936288      USD
# 2020-01-04  7345.1  7433.1  7291.4  7376.8  523909      USD
# 2020-01-05  7376.8  7501.0  7345.6  7372.5  628142      USD

# %%
bitcoin.Close.plot(figsize=(8,8))

# %%
ethereum = investpy.get_crypto_historical_data(crypto='ethereum', from_date='01/01/2020', to_date='06/11/2021')

# %%
ethereum.Close.plot(figsize=(6,6))

# %%
binance = investpy.get_crypto_historical_data(crypto='binance coin', from_date='01/01/2020', to_date='06/11/2021')

# %%
binance.Close.plot(figsize=(6,6))

# %%
solana = investpy.get_crypto_historical_data(crypto='solana', from_date='01/01/2020', to_date='06/11/2021')
solana.Close.plot(figsize=(7,7))

# %%
tether = investpy.get_crypto_historical_data(crypto='tether', from_date='01/01/2021', to_date='06/11/2021')
tether.Close.plot(figsize=(8,8))

# %%
cardano = investpy.get_crypto_historical_data(crypto='cardano', from_date='01/01/2021', to_date='06/11/2021')
cardano.Close.plot(figsize=(8,8))

# %%
xrp=investpy.get_crypto_historical_data(crypto='xrp', from_date='01/01/2021', to_date='06/11/2021')
xrp.Close.plot(figsize=(6,6))
