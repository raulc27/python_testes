# %% [markdown]
# <a href="https://colab.research.google.com/github/raulc27/python_testes/blob/master/rastreador_acoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
import yfinance as yf
import matplotlib.pyplot as plt

# %%
acoes = [
    'AAPL',
    'MSFT',
    'PETR4.SA',
    'BBDC4.SA'
]

# %%
dados_acoes = yf.download(acoes,
                          period='1d',
                          start='2022-01-01')
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
dados_acoes['Close'].plot()
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.title('Rastreador de ações')
plt.legend(acoes, fontsize=7)
plt.show()

# %%
dados_normalizados = dados_acoes['Close']/dados_acoes['Close'].iloc[0]
dados_normalizados.plot()
plt.xlabel('Data')
plt.ylabel('Preço Normalizado')
plt.title('Rastreador de ações')
plt.legend(acoes, fontsize=7)
plt.show()
